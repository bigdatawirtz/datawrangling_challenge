# %% [markdown]
# ### Ponemos encoding='cp1252' para que se pueda leer ya que está en otra codificación la cuan no se puede leer de manera normal.

# %%
import pandas as pd

datos = pd.read_csv("../../Datasets/dirty_dataset.csv", encoding='cp1252')

# %%
datos.head()
# Out:
#    País/Region!!          Region  Happiness Rank  SCORE_FELICIDAD (2015)  \
# 0    Switz3rland  WESTERN EUROPE               1                   7.587
# 1        Iceland  WESTERN EUROPE               2                   7.561
# 2        Denmark  WESTERN EUROPE               3                   7.527
# 3        Nor-way  WESTERN EUROPE               4                   7.522
# 4  Iván_espabila   NORTH AMERICA               5                   7.427
#
#    Standard Error    Economía   Family  Health (Life Expectancy)  Freedom  \
# 0         0.03411  1.39651 €   1,34951                   0.94143  0.66557
# 1         0.04884  1.30232 €   1,40223                   0.94784  0.62877
# 2         0.03328  1.32548 €   1,36058                   0.87464  0.64938
# 3         0.03880    1.459 €   1.33095                   0.88521  0.66973
# 4         0.03553  1.32629 €   1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...
