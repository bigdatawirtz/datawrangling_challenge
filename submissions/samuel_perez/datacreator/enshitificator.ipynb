# %% [markdown]
# # Dirty Data Wrangling Challenge
#
# ### Enshitificator 1.0
#
# La función de este cuaderno, será ensuciar el dataset de *"Hollywood 2025 Media Hype & Sentiment"*.
#
# Source: https://www.kaggle.com/datasets/kanchana1990/hollywood-2025-media-hype-and-sentiment
#
# El proceso de *enshitting* consta de las siguientes 10 partes:
#
# 1. Missing data: Remove or leave blank some values randomly.
#
# 2. Duplicated rows: Add exact or partial duplicates.
#
# 3. Outliers: Insert extreme values in numeric columns.
#
# 4. Format inconsistencies: Change date formats, numeric formats, or units.
#
# 5. Typographical errors: Introduce spelling mistakes in categorical columns.
#
# 6. Extra categories: Add unusual values in categorical columns to simulate errors.
#
# 7. Incorrect data types: Store numbers as strings or vice versa.
#
# 8. No default codification of file (utf-8?)
#
# 9. Incorrect headers
#
# 10. Extra punctuation symbols (1000€)
#
# Cada una de estas partes resultará en un error nuevo para el analista del dataset.

# %%
import pandas as pd
import numpy as np
import random

dirty_df = pd.read_csv("source_clean_dataset.csv")
display(dirty_df.head())
# Out:
#              Movie_Tag                                              Title  \
# 0  Avatar_Fire_and_Ash  All hail Avatar! How event movies are trying t...
# 1  Avatar_Fire_and_Ash  THE WEEKEND WARRIOR December 12, 2025 (Video E...
# 2  Avatar_Fire_and_Ash  Avatar: Fire And Ash Is Among The Most Expensi...
# 3  Avatar_Fire_and_Ash  6-Week Box Office Tracking & Forecasts: AVATAR...
# 4  Avatar_Fire_and_Ash  Why ‘Avatar: Fire and Ash’ Received Box Office...
#
#               Source         Publish_Date       Director  \
# 0       The Guardian  2025-12-09 16:17:00  James Cameron
# 1           Substack  2025-12-09 14:31:35  James Cameron
# 2          SlashFilm  2025-12-09 18:20:00  James Cameron
# 3  Box Office Theory  2025-12-05 17:25:52  James Cameron
# 4          Us Weekly  2025-12-08 20:54:04  James Cameron
#
#                                             Key_Cast           Genre  \
# 0  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 1  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 2  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 3  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 4  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
#
#                  Studio                                               Link  \
# 0  20th Century Studios  https://news.google.com/rss/articles/CBMiyAFBV...
# 1  20th Century Studios  https://news.google.com/rss/articles/CBMifkFVX...
# 2  20th Century Studios  https://news.google.com/rss/articles/CBMikgFBV...
# 3  20th Century Studios  https://news.google.com/rss/articles/CBMijgJBV...
# 4  20th Century Studios  https://news.google.com/rss/articles/CBMixAFBV...
#
#                                  Description_Snippet
# 0  All hail Avatar! How event movies are trying t...
# 1  THE WEEKEND WARRIOR December 12, 2025 (Video E...
# 2  Avatar: Fire And Ash Is Among The Most Expensi...
# 3  6-Week Box Office Tracking & Forecasts: AVATAR...
# 4  Why ‘Avatar: Fire and Ash’ Received Box Office...

# %% [markdown]
# ### 1. Missing data (valores faltantes)
#
# Seleccionamos el 5% de las celdas aleatoriamente y las dejamos en None

# %%
dirty_df.loc[
    dirty_df.sample(frac=0.05, random_state=42).index,
    "Studio"
] = None

display(dirty_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Movie_Tag            500 non-null    object
#  1   Title                500 non-null    object
#  2   Source               500 non-null    object
#  3   Publish_Date         500 non-null    object
#  4   Director             500 non-null    object
#  5   Key_Cast             500 non-null    object
#  6   Genre                500 non-null    object
#  7   Studio               475 non-null    object
#  8   Link                 500 non-null    object
#  9   Description_Snippet  500 non-null    object
# dtypes: object(10)
# memory usage: 39.2+ KB
# None

# %% [markdown]
# ### 3. Duplicated rows (filas duplicadas)
#
# Duplicamos algunas filas completas

# %%
duplicates = dirty_df.sample(10)
dirty_df = pd.concat([dirty_df, duplicates], ignore_index=True)

display(dirty_df[dirty_df.duplicated()].head())
# Out:
#                Movie_Tag                                              Title  \
# 500            Nosferatu  ‘Nosferatu’ review: Dir. Robert Eggers (2024) ...
# 501  Avatar_Fire_and_Ash  AVATAR: FIRE AND ASH First Reactions Describe ...
# 502            Nosferatu  Nosferatu: Old-World Devils and New-World Vict...
# 503               FNAF_2  'Weapons' ending breakdown: Unpacking those tw...
# 504               FNAF_2  Movie Review: 'Five Nights At Freddy’s 2' - Dr...
#
#                    Source         Publish_Date       Director  \
# 500    The Hollywood News  2024-12-17 08:00:00  Robert Eggers
# 501    ComicBookMovie.com  2025-12-02 13:12:00  James Cameron
# 502       Crisis Magazine  2025-01-13 08:00:00  Robert Eggers
# 503  Entertainment Weekly  2025-08-08 07:00:00     Emma Tammi
# 504        DrydenWire.com  2025-12-08 16:24:14     Emma Tammi
#
#                                               Key_Cast           Genre Studio  \
# 500     Bill Skarsgård, Lily-Rose Depp, Nicholas Hoult   Gothic Horror   None
# 501  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy   None
# 502     Bill Skarsgård, Lily-Rose Depp, Nicholas Hoult   Gothic Horror   None
# 503  Josh Hutcherson, Matthew Lillard, Elizabeth La...          Horror   None
# 504  Josh Hutcherson, Matthew Lillard, Elizabeth La...          Horror   None
#
#                                                   Link  \
# 500  https://news.google.com/rss/articles/CBMihwFBV...
# 501  https://news.google.com/rss/articles/CBMi5AFBV...
# 502  https://news.google.com/rss/articles/CBMiiwFBV...
# 503  https://news.google.com/rss/articles/CBMiiAFBV...
# 504  https://news.google.com/rss/articles/CBMidEFVX...
#
#                                    Description_Snippet
# 500  ‘Nosferatu’ review: Dir. Robert Eggers (2024)&...
# 501  AVATAR: FIRE AND ASH First Reactions Describe ...
# 502  Nosferatu: Old-World Devils and New-World Vict...
# 503  'Weapons' ending breakdown: Unpacking those tw...
# 504  Movie Review: 'Five Nights At Freddy’s 2'&nbsp...

# %% [markdown]
# ### 4. Partial duplicates (duplicados parciales)

# %%
partial_duplicates = dirty_df.sample(5).copy()
if len(dirty_df.columns) > 1:
    partial_duplicates.iloc[:, 0] = dirty_df.iloc[0, 0]
dirty_df = pd.concat([dirty_df, partial_duplicates], ignore_index=True)

display(dirty_df[dirty_df.duplicated()].head())
# Out:
#                Movie_Tag                                              Title  \
# 500            Nosferatu  ‘Nosferatu’ review: Dir. Robert Eggers (2024) ...
# 501  Avatar_Fire_and_Ash  AVATAR: FIRE AND ASH First Reactions Describe ...
# 502            Nosferatu  Nosferatu: Old-World Devils and New-World Vict...
# 503               FNAF_2  'Weapons' ending breakdown: Unpacking those tw...
# 504               FNAF_2  Movie Review: 'Five Nights At Freddy’s 2' - Dr...
#
#                    Source         Publish_Date       Director  \
# 500    The Hollywood News  2024-12-17 08:00:00  Robert Eggers
# 501    ComicBookMovie.com  2025-12-02 13:12:00  James Cameron
# 502       Crisis Magazine  2025-01-13 08:00:00  Robert Eggers
# 503  Entertainment Weekly  2025-08-08 07:00:00     Emma Tammi
# 504        DrydenWire.com  2025-12-08 16:24:14     Emma Tammi
#
#                                               Key_Cast           Genre Studio  \
# 500     Bill Skarsgård, Lily-Rose Depp, Nicholas Hoult   Gothic Horror   None
# 501  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy   None
# 502     Bill Skarsgård, Lily-Rose Depp, Nicholas Hoult   Gothic Horror   None
# 503  Josh Hutcherson, Matthew Lillard, Elizabeth La...          Horror   None
# 504  Josh Hutcherson, Matthew Lillard, Elizabeth La...          Horror   None
#
#                                                   Link  \
# 500  https://news.google.com/rss/articles/CBMihwFBV...
# 501  https://news.google.com/rss/articles/CBMi5AFBV...
# 502  https://news.google.com/rss/articles/CBMiiwFBV...
# 503  https://news.google.com/rss/articles/CBMiiAFBV...
# 504  https://news.google.com/rss/articles/CBMidEFVX...
#
#                                    Description_Snippet
# 500  ‘Nosferatu’ review: Dir. Robert Eggers (2024)&...
# 501  AVATAR: FIRE AND ASH First Reactions Describe ...
# 502  Nosferatu: Old-World Devils and New-World Vict...
# 503  'Weapons' ending breakdown: Unpacking those tw...
# 504  Movie Review: 'Five Nights At Freddy’s 2'&nbsp...

# %% [markdown]
# ### 5. Outliers (valores extremos)
#
# Usamos índices aleatorios pero reproducibles, luego introducimos un par de fechas extremadamente fuera de rango.

# %%
np.random.seed(42)

outlier_indices = np.random.choice(
    dirty_df.index,
    size=2,
    replace=False
)
 
dirty_df.loc[outlier_indices[0], "Publish_Date"] = pd.Timestamp("1800-01-01")
dirty_df.loc[outlier_indices[1], "Publish_Date"] = pd.Timestamp("2200-12-31")
show = dirty_df.loc[outlier_indices[1]], dirty_df.loc[outlier_indices[0]]
display(show)
# Out:
# (Movie_Tag                                                      Mickey_17
#  Title                  Mickey 17 Review: Uneven but undeniably entert...
#  Source                                                             JoBlo
#  Publish_Date                                         2200-12-31 00:00:00
#  Director                                                    Bong Joon-ho
#  Key_Cast                     Robert Pattinson, Steven Yeun, Mark Ruffalo
#  Genre                                                       Sci-Fi/Drama
#  Studio                                                      Warner Bros.
#  Link                   https://news.google.com/rss/articles/CBMiUEFVX...
#  Description_Snippet    Mickey 17 Review: Uneven but undeniably entert...
#  Name: 499, dtype: object,
#  Movie_Tag                                                      Nosferatu
#  Title                  ‘Nosferatu’ Review: Excellent Cinematography A...
#  Source                                              Bounding Into Comics
#  Publish_Date                                         1800-01-01 00:00:00
#  Director                                                   Robert Eggers
#  Key_Cast                  Bill Skarsgård, Lily-Rose Depp, Nicholas Hoult
#  Genre                                                      Gothic Horror
#  Studio                                                    Focus Features
#  Link                   https://news.google.com/rss/articles/CBMi9AFBV...
#  Description_Snippet    ‘Nosferatu’ Review: Excellent Cinematography A...
#  Name: 304, dtype: object)

# %% [markdown]
# # 6. Format inconsistencies (formatos inconsistentes)
#
# Si hay una columna de fechas, cambiamos formatos

# %%
date_cols = dirty_df.select_dtypes(include=["object"]).columns

for col in date_cols:
    if "publish_date" in col.lower():
        dirty_df.loc[dirty_df.sample(5).index, col] = [
            "01-02-2025", "2025/02/01", "Feb 1, 2025", "2025.02.01", "01/02/25"
        ]

display(dirty_df[dirty_df['Publish_Date'] == "Feb 1, 2025"].head())
# Out:
#      Movie_Tag                                              Title  \
# 441  Mickey_17  Review: Bong Joon-ho's Mickey 17 is doing a lo...
#
#             Source Publish_Date      Director  \
# 441  Lainey Gossip  Feb 1, 2025  Bong Joon-ho
#
#                                         Key_Cast         Genre        Studio  \
# 441  Robert Pattinson, Steven Yeun, Mark Ruffalo  Sci-Fi/Drama  Warner Bros.
#
#                                                   Link  \
# 441  https://news.google.com/rss/articles/CBMimwFBV...
#
#                                    Description_Snippet
# 441  Review: Bong Joon-ho's Mickey 17 is doing a lo...

# %% [markdown]
# # 7. Typographical errors (errores tipográficos)
#
# Introducimos errores de escritura en columnas categóricas

# %%
for col in dirty_df.select_dtypes(include=["object"]).columns:
    dirty_df.loc[dirty_df.sample(3).index, col] = "unknwon"

display(dirty_df[dirty_df['Link'] == "unknwon"].head())
# Out:
#                Movie_Tag                                              Title  \
# 94   Avatar_Fire_and_Ash          FYI: New ‘Avatar’ Movie Long AF - Gizmodo
# 451            Mickey_17  Mickey 17 Review: So Relatable That It Is Terr...
# 475            Mickey_17  'Mickey 17' Review: Quirky, Refreshing Sci-FI ...
#
#            Source         Publish_Date       Director  \
# 94        Gizmodo  2025-11-12 08:00:00  James Cameron
# 451  Mama's Geeky  2025-03-05 08:00:00   Bong Joon-ho
# 475     FilmSpeak  2025-03-07 08:00:00   Bong Joon-ho
#
#                                               Key_Cast           Genre  \
# 94   Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 451        Robert Pattinson, Steven Yeun, Mark Ruffalo    Sci-Fi/Drama
# 475        Robert Pattinson, Steven Yeun, Mark Ruffalo    Sci-Fi/Drama
#
#                    Studio     Link  \
# 94   20th Century Studios  unknwon
# 451          Warner Bros.  unknwon
# 475          Warner Bros.  unknwon
#
#                                    Description_Snippet
# 94   FYI: New ‘Avatar’ Movie Long AF&nbsp;&nbsp;Giz...
# 451  Mickey 17 Review: So Relatable That It Is Terr...
# 475  'Mickey 17' Review: Quirky, Refreshing Sci-FI&...

# %% [markdown]
# # 8. Extra categories (categorías inesperadas)

# %%
for col in dirty_df.select_dtypes(include=["object"]).columns:
    dirty_df.loc[dirty_df.sample(3).index, col] = "###ERROR###"
    
display(dirty_df[dirty_df['Movie_Tag'] == "###ERROR###"].head())
# Out:
#        Movie_Tag                                              Title  \
# 70   ###ERROR###  James Cameron Could End 'Avatar' With 'Fire an...
# 240  ###ERROR###  Sonic The Hedgehog 3 Lands Another Impressive ...
# 512  ###ERROR###  AVATAR: FIRE AND ASH First Reactions Describe ...
#
#                  Source         Publish_Date       Director  \
# 70             MovieWeb  2025-11-26 08:00:00  James Cameron
# 240         Screen Rant  2025-01-28 08:00:00    Jeff Fowler
# 512  ComicBookMovie.com  2025-12-02 13:12:00  James Cameron
#
#                                               Key_Cast             Genre  \
# 70   Sam Worthington, Zoe Saldaña, Sigourney Weaver...    Sci-Fi/Fantasy
# 240  Ben Schwartz, Jim Carrey, Keanu Reeves (Shadow...  Action/Adventure
# 512  Sam Worthington, Zoe Saldaña, Sigourney Weaver...    Sci-Fi/Fantasy
#
#                    Studio                                               Link  \
# 70   20th Century Studios  https://news.google.com/rss/articles/CBMihgFBV...
# 240             Paramount  https://news.google.com/rss/articles/CBMitgFBV...
# 512                  None  https://news.google.com/rss/articles/CBMi5AFBV...
#
#                                    Description_Snippet
# 70   James Cameron Could End 'Avatar' With 'Fire an...
# 240  Sonic The Hedgehog 3 Lands Another Impressive ...
# 512  AVATAR: FIRE AND ASH First Reactions Describe ...

# %% [markdown]
# # 9. Incorrect data types (tipos incorrectos)
#
# Cogemos la columna Source y cambiamos un par de registros a formato JSON

# %%
# Utilizamos una semilla
np.random.seed(42)
indices = dirty_df.sample(3, random_state=42).index

# Convertimos esos valores a JSON manualmente (string)
dirty_df.loc[indices, 'Source'] = (
    dirty_df.loc[indices, 'Source']
    .apply(lambda x: {"Source": x})
    .apply(lambda x: str(x))
)

display(dirty_df.loc[indices])
# Out:
#      Movie_Tag                                              Title  \
# 304  Nosferatu  ‘Nosferatu’ Review: Excellent Cinematography A...
# 499  Mickey_17  Mickey 17 Review: Uneven but undeniably entert...
# 441  Mickey_17  Review: Bong Joon-ho's Mickey 17 is doing a lo...
#
#                                  Source         Publish_Date       Director  \
# 304  {'Source': 'Bounding Into Comics'}  1800-01-01 00:00:00  Robert Eggers
# 499                 {'Source': 'JoBlo'}  2200-12-31 00:00:00   Bong Joon-ho
# 441         {'Source': 'Lainey Gossip'}          Feb 1, 2025   Bong Joon-ho
#
#                                            Key_Cast          Genre  \
# 304  Bill Skarsgård, Lily-Rose Depp, Nicholas Hoult  Gothic Horror
# 499     Robert Pattinson, Steven Yeun, Mark Ruffalo   Sci-Fi/Drama
# 441     Robert Pattinson, Steven Yeun, Mark Ruffalo   Sci-Fi/Drama
#
#              Studio                                               Link  \
# 304  Focus Features  https://news.google.com/rss/articles/CBMi9AFBV...
# 499    Warner Bros.  https://news.google.com/rss/articles/CBMiUEFVX...
# 441    Warner Bros.  https://news.google.com/rss/articles/CBMimwFBV...
#
#                                    Description_Snippet
# 304  ‘Nosferatu’ Review: Excellent Cinematography A...
# 499  Mickey 17 Review: Uneven but undeniably entert...
# 441  Review: Bong Joon-ho's Mickey 17 is doing a lo...

# %% [markdown]
# ### 10. Incorrect headers

# %%
dirty_df.columns = [
    col + random.choice(["&", "##", "!!!"]) for col in dirty_df.columns
]

display(dirty_df.head())
# Out:
#            Movie_Tag##                                            Title##  \
# 0  Avatar_Fire_and_Ash  All hail Avatar! How event movies are trying t...
# 1  Avatar_Fire_and_Ash  THE WEEKEND WARRIOR December 12, 2025 (Video E...
# 2  Avatar_Fire_and_Ash  Avatar: Fire And Ash Is Among The Most Expensi...
# 3  Avatar_Fire_and_Ash                                        ###ERROR###
# 4  Avatar_Fire_and_Ash  Why ‘Avatar: Fire and Ash’ Received Box Office...
#
#             Source##      Publish_Date!!!     Director##  \
# 0       The Guardian  2025-12-09 16:17:00  James Cameron
# 1           Substack  2025-12-09 14:31:35  James Cameron
# 2          SlashFilm  2025-12-09 18:20:00  James Cameron
# 3  Box Office Theory  2025-12-05 17:25:52  James Cameron
# 4          Us Weekly  2025-12-08 20:54:04  James Cameron
#
#                                            Key_Cast&          Genre&  \
# 0  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 1  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 2  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 3  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
# 4  Sam Worthington, Zoe Saldaña, Sigourney Weaver...  Sci-Fi/Fantasy
#
#                 Studio&                                            Link!!!  \
# 0  20th Century Studios  https://news.google.com/rss/articles/CBMiyAFBV...
# 1  20th Century Studios  https://news.google.com/rss/articles/CBMifkFVX...
# 2  20th Century Studios  https://news.google.com/rss/articles/CBMikgFBV...
# 3  20th Century Studios  https://news.google.com/rss/articles/CBMijgJBV...
# 4  20th Century Studios  https://news.google.com/rss/articles/CBMixAFBV...
#
#                                Description_Snippet##
# 0  All hail Avatar! How event movies are trying t...
# 1  THE WEEKEND WARRIOR December 12, 2025 (Video E...
# 2                                            unknwon
# 3  6-Week Box Office Tracking & Forecasts: AVATAR...
# 4  Why ‘Avatar: Fire and Ash’ Received Box Office...

# %% [markdown]
# ### 12. Encoding issue (no UTF-8 explícito)
#
# Guardamos el archivo sin especificar encoding (simula problemas)

# %%
dirty_df.to_csv("dirty_dataset.csv", index=False, encoding="UTF-8")
